# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.datasets import cifar10

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
x_train = x_train.astype('float32')/255.0
x_test = x_test.astype('float32')/255.0

# %%
model = keras.Sequential([
    keras.Input(shape=(32,32,3)),
    layers.Conv2D(32, 3, activation = 'relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(64, 3, activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(128, 3, activation = 'relu'),
    layers.Flatten(),
    layers.Dense(64, activation = 'relu'),
    layers.Dense(10),
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)         73856
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 64)                131136
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 225034 (879.04 KB)
# Trainable params: 225034 (879.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
def my_model():
    inputs = keras.Input(shape=(32, 32, 3))
    x = layers.Conv2D(32, 3, padding="same", kernel_regularizer=regularizers.l2(0.01),)(
        inputs
    )
    x = layers.BatchNormalization()(x)
    x = keras.activations.relu(x)
    x = layers.MaxPooling2D()(x)
    x = layers.Conv2D(64, 3, padding="same", kernel_regularizer=regularizers.l2(0.01),)(
        x
    )
    x = layers.BatchNormalization()(x)
    x = keras.activations.relu(x)
    x = layers.MaxPooling2D()(x)
    x = layers.Conv2D(
        128, 3, padding="same", kernel_regularizer=regularizers.l2(0.01),
    )(x)
    x = layers.BatchNormalization()(x)
    x = keras.activations.relu(x)
    x = layers.Flatten()(x)
    x = layers.Dense(64, activation="relu", kernel_regularizer=regularizers.l2(0.01),)(
        x
    )
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(10)(x)
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = my_model()
model.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits = True),
    optimizer=keras.optimizers.Adam(),
    metrics = ['accuracy'],
)

# %%
model.fit(x_train, y_train, batch_size=64, epochs=150, verbose=2)
# Out:
# Epoch 1/150
# 782/782 - 6s - loss: 1.9790 - accuracy: 0.2567 - 6s/epoch - 8ms/step
# Epoch 2/150
# 782/782 - 6s - loss: 1.9690 - accuracy: 0.2616 - 6s/epoch - 8ms/step
# Epoch 3/150
# 782/782 - 6s - loss: 1.9529 - accuracy: 0.2680 - 6s/epoch - 8ms/step
# Epoch 4/150
# 782/782 - 6s - loss: 1.9305 - accuracy: 0.2765 - 6s/epoch - 8ms/step
# Epoch 5/150
# 782/782 - 7s - loss: 1.9188 - accuracy: 0.2790 - 7s/epoch - 9ms/step
# Epoch 6/150
# 782/782 - 6s - loss: 1.9023 - accuracy: 0.2846 - 6s/epoch - 8ms/step
# Epoch 7/150
# 782/782 - 6s - loss: 1.8884 - accuracy: 0.2910 - 6s/epoch - 7ms/step
# Epoch 8/150
# 782/782 - 6s - loss: 1.8811 - accuracy: 0.2905 - 6s/epoch - 7ms/step
# Epoch 9/150
# 782/782 - 6s - loss: 1.8727 - accuracy: 0.3007 - 6s/epoch - 7ms/step
# Epoch 10/150
# 782/782 - 6s - loss: 1.8611 - accuracy: 0.3071 - 6s/epoch - 7ms/step
# Epoch 11/150
# 782/782 - 6s - loss: 1.8599 - accuracy: 0.3048 - 6s/epoch - 8ms/step
# Epoch 12/150
# 782/782 - 6s - loss: 1.8496 - accuracy: 0.3099 - 6s/epoch - 7ms/step
# Epoch 13/150
# 782/782 - 6s - loss: 1.8459 - accuracy: 0.3078 - 6s/epoch - 7ms/step
# Epoch 14/150
# 782/782 - 6s - loss: 1.8441 - accuracy: 0.3083 - 6s/epoch - 7ms/step
# Epoch 15/150
# 782/782 - 6s - loss: 1.8366 - accuracy: 0.3142 - 6s/epoch - 7ms/step
# Epoch 16/150
# 782/782 - 6s - loss: 1.8331 - accuracy: 0.3144 - 6s/epoch - 7ms/step
# Epoch 17/150
# 782/782 - 6s - loss: 1.8336 - accuracy: 0.3174 - 6s/epoch - 7ms/step
# Epoch 18/150
# 782/782 - 6s - loss: 1.8325 - accuracy: 0.3160 - 6s/epoch - 7ms/step
# Epoch 19/150
# 782/782 - 6s - loss: 1.8272 - accuracy: 0.3179 - 6s/epoch - 7ms/step
# Epoch 20/150
# 782/782 - 6s - loss: 1.8231 - accuracy: 0.3191 - 6s/epoch - 7ms/step
# Epoch 21/150
# 782/782 - 6s - loss: 1.8191 - accuracy: 0.3190 - 6s/epoch - 7ms/step
# Epoch 22/150
# 782/782 - 6s - loss: 1.8231 - accuracy: 0.3098 - 6s/epoch - 7ms/step
# Epoch 23/150
# 782/782 - 6s - loss: 1.8178 - accuracy: 0.3122 - 6s/epoch - 7ms/step
# Epoch 24/150
# 782/782 - 6s - loss: 1.8236 - accuracy: 0.3149 - 6s/epoch - 7ms/step
# Epoch 25/150
# 782/782 - 6s - loss: 1.8176 - accuracy: 0.3229 - 6s/epoch - 7ms/step
# Epoch 26/150
# 782/782 - 6s - loss: 1.8192 - accuracy: 0.3245 - 6s/epoch - 7ms/step
# Epoch 27/150
# 782/782 - 6s - loss: 1.8178 - accuracy: 0.3233 - 6s/epoch - 7ms/step
# Epoch 28/150
# 782/782 - 6s - loss: 1.8074 - accuracy: 0.3289 - 6s/epoch - 7ms/step
# Epoch 29/150
# 782/782 - 6s - loss: 1.8149 - accuracy: 0.3213 - 6s/epoch - 7ms/step
# Epoch 30/150
# 782/782 - 6s - loss: 1.8135 - accuracy: 0.3251 - 6s/epoch - 8ms/step
# Epoch 31/150
# 782/782 - 6s - loss: 1.8080 - accuracy: 0.3260 - 6s/epoch - 7ms/step
# Epoch 32/150
# 782/782 - 6s - loss: 1.8114 - accuracy: 0.3267 - 6s/epoch - 8ms/step
# Epoch 33/150
# 782/782 - 6s - loss: 1.8113 - accuracy: 0.3233 - 6s/epoch - 7ms/step
# Epoch 34/150
# 782/782 - 6s - loss: 1.8089 - accuracy: 0.3268 - 6s/epoch - 7ms/step
# Epoch 35/150
# 782/782 - 6s - loss: 1.8125 - accuracy: 0.3233 - 6s/epoch - 7ms/step
# Epoch 36/150
# 782/782 - 6s - loss: 1.8069 - accuracy: 0.3250 - 6s/epoch - 7ms/step
# Epoch 37/150
# 782/782 - 6s - loss: 1.8035 - accuracy: 0.3228 - 6s/epoch - 7ms/step
# Epoch 38/150
# 782/782 - 6s - loss: 1.8074 - accuracy: 0.3216 - 6s/epoch - 7ms/step
# Epoch 39/150
# 782/782 - 6s - loss: 1.8056 - accuracy: 0.3206 - 6s/epoch - 7ms/step
# Epoch 40/150
# 782/782 - 6s - loss: 1.8041 - accuracy: 0.3280 - 6s/epoch - 7ms/step
# Epoch 41/150
# 782/782 - 6s - loss: 1.8094 - accuracy: 0.3247 - 6s/epoch - 7ms/step
# Epoch 42/150
# 782/782 - 6s - loss: 1.8001 - accuracy: 0.3250 - 6s/epoch - 8ms/step
# Epoch 43/150
# 782/782 - 6s - loss: 1.8054 - accuracy: 0.3311 - 6s/epoch - 7ms/step
# Epoch 44/150
# 782/782 - 6s - loss: 1.7993 - accuracy: 0.3291 - 6s/epoch - 7ms/step
# Epoch 45/150
# 782/782 - 6s - loss: 1.8106 - accuracy: 0.3239 - 6s/epoch - 7ms/step
# Epoch 46/150
# 782/782 - 6s - loss: 1.8067 - accuracy: 0.3256 - 6s/epoch - 7ms/step
# Epoch 47/150
# 782/782 - 6s - loss: 1.8058 - accuracy: 0.3235 - 6s/epoch - 7ms/step
# Epoch 48/150
# 782/782 - 6s - loss: 1.8058 - accuracy: 0.3249 - 6s/epoch - 7ms/step
# Epoch 49/150
# 782/782 - 6s - loss: 1.8008 - accuracy: 0.3262 - 6s/epoch - 7ms/step
# Epoch 50/150
# 782/782 - 6s - loss: 1.8001 - accuracy: 0.3277 - 6s/epoch - 7ms/step
# Epoch 51/150
# 782/782 - 6s - loss: 1.8010 - accuracy: 0.3228 - 6s/epoch - 7ms/step
# Epoch 52/150
# 782/782 - 6s - loss: 1.7966 - accuracy: 0.3270 - 6s/epoch - 7ms/step
# Epoch 53/150
# 782/782 - 6s - loss: 1.8061 - accuracy: 0.3218 - 6s/epoch - 7ms/step
# Epoch 54/150
# 782/782 - 6s - loss: 1.7996 - accuracy: 0.3251 - 6s/epoch - 7ms/step
# Epoch 55/150
# 782/782 - 6s - loss: 1.8007 - accuracy: 0.3294 - 6s/epoch - 7ms/step
# Epoch 56/150
# 782/782 - 6s - loss: 1.7981 - accuracy: 0.3316 - 6s/epoch - 7ms/step
# Epoch 57/150
# 782/782 - 6s - loss: 1.7969 - accuracy: 0.3356 - 6s/epoch - 7ms/step
# Epoch 58/150
# 782/782 - 6s - loss: 1.7941 - accuracy: 0.3328 - 6s/epoch - 7ms/step
# Epoch 59/150
# 782/782 - 6s - loss: 1.7978 - accuracy: 0.3262 - 6s/epoch - 7ms/step
# Epoch 60/150
# 782/782 - 6s - loss: 1.7969 - accuracy: 0.3240 - 6s/epoch - 7ms/step
# Epoch 61/150
# 782/782 - 6s - loss: 1.8000 - accuracy: 0.3290 - 6s/epoch - 7ms/step
# Epoch 62/150
# 782/782 - 6s - loss: 1.7933 - accuracy: 0.3265 - 6s/epoch - 7ms/step
# Epoch 63/150
# 782/782 - 6s - loss: 1.8005 - accuracy: 0.3262 - 6s/epoch - 7ms/step
# Epoch 64/150
# 782/782 - 6s - loss: 1.7962 - accuracy: 0.3268 - 6s/epoch - 7ms/step
# Epoch 65/150
# 782/782 - 6s - loss: 1.8059 - accuracy: 0.3223 - 6s/epoch - 7ms/step
# Epoch 66/150
# 782/782 - 6s - loss: 1.8013 - accuracy: 0.3226 - 6s/epoch - 7ms/step
# Epoch 67/150
# 782/782 - 6s - loss: 1.7990 - accuracy: 0.3254 - 6s/epoch - 7ms/step
# Epoch 68/150
# 782/782 - 6s - loss: 1.8005 - accuracy: 0.3245 - 6s/epoch - 7ms/step
# Epoch 69/150
# 782/782 - 6s - loss: 1.7976 - accuracy: 0.3301 - 6s/epoch - 7ms/step
# Epoch 70/150
# 782/782 - 6s - loss: 1.7954 - accuracy: 0.3293 - 6s/epoch - 7ms/step
# Epoch 71/150
# 782/782 - 6s - loss: 1.7994 - accuracy: 0.3273 - 6s/epoch - 7ms/step
# Epoch 72/150
# 782/782 - 6s - loss: 1.8015 - accuracy: 0.3311 - 6s/epoch - 7ms/step
# Epoch 73/150
# 782/782 - 6s - loss: 1.8000 - accuracy: 0.3320 - 6s/epoch - 7ms/step
# Epoch 74/150
# 782/782 - 6s - loss: 1.7986 - accuracy: 0.3296 - 6s/epoch - 7ms/step
# Epoch 75/150
# 782/782 - 6s - loss: 1.7906 - accuracy: 0.3302 - 6s/epoch - 7ms/step
# Epoch 76/150
# 782/782 - 6s - loss: 1.7934 - accuracy: 0.3377 - 6s/epoch - 7ms/step
# Epoch 77/150
# 782/782 - 6s - loss: 1.7906 - accuracy: 0.3329 - 6s/epoch - 7ms/step
# Epoch 78/150
# 782/782 - 6s - loss: 1.8015 - accuracy: 0.3316 - 6s/epoch - 7ms/step
# Epoch 79/150
# 782/782 - 6s - loss: 1.7962 - accuracy: 0.3307 - 6s/epoch - 7ms/step
# Epoch 80/150
# 782/782 - 6s - loss: 1.7984 - accuracy: 0.3288 - 6s/epoch - 7ms/step
# Epoch 81/150
# 782/782 - 6s - loss: 1.7930 - accuracy: 0.3290 - 6s/epoch - 7ms/step
# Epoch 82/150
# 782/782 - 6s - loss: 1.7989 - accuracy: 0.3293 - 6s/epoch - 7ms/step
# Epoch 83/150
# 782/782 - 6s - loss: 1.7995 - accuracy: 0.3322 - 6s/epoch - 7ms/step
# Epoch 84/150
# 782/782 - 6s - loss: 1.7944 - accuracy: 0.3251 - 6s/epoch - 7ms/step
# Epoch 85/150
# 782/782 - 6s - loss: 1.7911 - accuracy: 0.3354 - 6s/epoch - 7ms/step
# Epoch 86/150
# 782/782 - 5s - loss: 1.7961 - accuracy: 0.3326 - 5s/epoch - 7ms/step
# Epoch 87/150
# 782/782 - 6s - loss: 1.8013 - accuracy: 0.3310 - 6s/epoch - 7ms/step
# Epoch 88/150
# 782/782 - 6s - loss: 1.8025 - accuracy: 0.3228 - 6s/epoch - 8ms/step
# Epoch 89/150
# 782/782 - 6s - loss: 1.7915 - accuracy: 0.3314 - 6s/epoch - 7ms/step
# Epoch 90/150
# 782/782 - 6s - loss: 1.7917 - accuracy: 0.3317 - 6s/epoch - 7ms/step
# Epoch 91/150
# 782/782 - 6s - loss: 1.7988 - accuracy: 0.3294 - 6s/epoch - 7ms/step
# Epoch 92/150
# 782/782 - 6s - loss: 1.7908 - accuracy: 0.3299 - 6s/epoch - 7ms/step
# Epoch 93/150
# 782/782 - 6s - loss: 1.7918 - accuracy: 0.3308 - 6s/epoch - 7ms/step
# Epoch 94/150
# 782/782 - 6s - loss: 1.7907 - accuracy: 0.3297 - 6s/epoch - 7ms/step
# Epoch 95/150
# 782/782 - 6s - loss: 1.7923 - accuracy: 0.3298 - 6s/epoch - 7ms/step
# Epoch 96/150
# 782/782 - 6s - loss: 1.7863 - accuracy: 0.3305 - 6s/epoch - 7ms/step
# Epoch 97/150
# 782/782 - 6s - loss: 1.7943 - accuracy: 0.3377 - 6s/epoch - 7ms/step
# Epoch 98/150
# 782/782 - 6s - loss: 1.7953 - accuracy: 0.3384 - 6s/epoch - 7ms/step
# Epoch 99/150
# 782/782 - 6s - loss: 1.7914 - accuracy: 0.3369 - 6s/epoch - 7ms/step
# Epoch 100/150
# 782/782 - 6s - loss: 1.7910 - accuracy: 0.3347 - 6s/epoch - 7ms/step
# Epoch 101/150
# 782/782 - 6s - loss: 1.7897 - accuracy: 0.3354 - 6s/epoch - 7ms/step
# Epoch 102/150
# 782/782 - 6s - loss: 1.7922 - accuracy: 0.3340 - 6s/epoch - 7ms/step
# Epoch 103/150
# 782/782 - 6s - loss: 1.7935 - accuracy: 0.3316 - 6s/epoch - 7ms/step
# Epoch 104/150
# 782/782 - 6s - loss: 1.7990 - accuracy: 0.3257 - 6s/epoch - 7ms/step
# Epoch 105/150
# 782/782 - 6s - loss: 1.7956 - accuracy: 0.3315 - 6s/epoch - 7ms/step
# Epoch 106/150
# 782/782 - 6s - loss: 1.7886 - accuracy: 0.3341 - 6s/epoch - 7ms/step
# Epoch 107/150
# 782/782 - 6s - loss: 1.7959 - accuracy: 0.3343 - 6s/epoch - 7ms/step
# Epoch 108/150
# 782/782 - 6s - loss: 1.7937 - accuracy: 0.3369 - 6s/epoch - 7ms/step
# Epoch 109/150
# 782/782 - 6s - loss: 1.7980 - accuracy: 0.3340 - 6s/epoch - 7ms/step
# Epoch 110/150
# 782/782 - 6s - loss: 1.7947 - accuracy: 0.3326 - 6s/epoch - 7ms/step
# Epoch 111/150
# 782/782 - 6s - loss: 1.7961 - accuracy: 0.3384 - 6s/epoch - 8ms/step
# Epoch 112/150
# 782/782 - 6s - loss: 1.7964 - accuracy: 0.3360 - 6s/epoch - 7ms/step
# Epoch 113/150
# 782/782 - 6s - loss: 1.7895 - accuracy: 0.3397 - 6s/epoch - 7ms/step
# Epoch 114/150
# 782/782 - 6s - loss: 1.7903 - accuracy: 0.3356 - 6s/epoch - 7ms/step
# Epoch 115/150
# 782/782 - 6s - loss: 1.7918 - accuracy: 0.3371 - 6s/epoch - 7ms/step
# Epoch 116/150
# 782/782 - 6s - loss: 1.7960 - accuracy: 0.3389 - 6s/epoch - 7ms/step
# Epoch 117/150
# 782/782 - 6s - loss: 1.7923 - accuracy: 0.3384 - 6s/epoch - 7ms/step
# Epoch 118/150
# 782/782 - 6s - loss: 1.7952 - accuracy: 0.3361 - 6s/epoch - 7ms/step
# Epoch 119/150
# 782/782 - 6s - loss: 1.7980 - accuracy: 0.3358 - 6s/epoch - 7ms/step
# Epoch 120/150
# 782/782 - 6s - loss: 1.7966 - accuracy: 0.3342 - 6s/epoch - 7ms/step
# Epoch 121/150
# 782/782 - 6s - loss: 1.7902 - accuracy: 0.3360 - 6s/epoch - 7ms/step
# Epoch 122/150
# 782/782 - 6s - loss: 1.7992 - accuracy: 0.3301 - 6s/epoch - 7ms/step
# Epoch 123/150
# 782/782 - 5s - loss: 1.7946 - accuracy: 0.3365 - 5s/epoch - 7ms/step
# Epoch 124/150
# 782/782 - 6s - loss: 1.7936 - accuracy: 0.3373 - 6s/epoch - 7ms/step
# Epoch 125/150
# 782/782 - 6s - loss: 1.7963 - accuracy: 0.3352 - 6s/epoch - 7ms/step
# Epoch 126/150
# 782/782 - 6s - loss: 1.7899 - accuracy: 0.3344 - 6s/epoch - 7ms/step
# Epoch 127/150
# 782/782 - 6s - loss: 1.7900 - accuracy: 0.3350 - 6s/epoch - 7ms/step
# Epoch 128/150
# 782/782 - 6s - loss: 1.7977 - accuracy: 0.3355 - 6s/epoch - 7ms/step
# Epoch 129/150
# 782/782 - 6s - loss: 1.7942 - accuracy: 0.3371 - 6s/epoch - 7ms/step
# Epoch 130/150
# 782/782 - 6s - loss: 1.7922 - accuracy: 0.3369 - 6s/epoch - 7ms/step
# Epoch 131/150
# 782/782 - 6s - loss: 1.7926 - accuracy: 0.3339 - 6s/epoch - 7ms/step
# Epoch 132/150
# 782/782 - 6s - loss: 1.7952 - accuracy: 0.3346 - 6s/epoch - 7ms/step
# Epoch 133/150
# 782/782 - 6s - loss: 1.7964 - accuracy: 0.3386 - 6s/epoch - 7ms/step
# Epoch 134/150
# 782/782 - 6s - loss: 1.7936 - accuracy: 0.3382 - 6s/epoch - 7ms/step
# Epoch 135/150
# 782/782 - 6s - loss: 1.7913 - accuracy: 0.3385 - 6s/epoch - 7ms/step
# Epoch 136/150
# 782/782 - 6s - loss: 1.7935 - accuracy: 0.3372 - 6s/epoch - 7ms/step
# Epoch 137/150
# 782/782 - 6s - loss: 1.7973 - accuracy: 0.3318 - 6s/epoch - 7ms/step
# Epoch 138/150
# 782/782 - 6s - loss: 1.7978 - accuracy: 0.3361 - 6s/epoch - 8ms/step
# Epoch 139/150
# 782/782 - 6s - loss: 1.7938 - accuracy: 0.3346 - 6s/epoch - 7ms/step
# Epoch 140/150
# 782/782 - 6s - loss: 1.7870 - accuracy: 0.3358 - 6s/epoch - 7ms/step
# Epoch 141/150
# 782/782 - 6s - loss: 1.7939 - accuracy: 0.3350 - 6s/epoch - 7ms/step
# Epoch 142/150
# 782/782 - 6s - loss: 1.7955 - accuracy: 0.3309 - 6s/epoch - 7ms/step
# Epoch 143/150
# 782/782 - 6s - loss: 1.7944 - accuracy: 0.3296 - 6s/epoch - 7ms/step
# Epoch 144/150
# 782/782 - 6s - loss: 1.7918 - accuracy: 0.3311 - 6s/epoch - 7ms/step
# Epoch 145/150
# 782/782 - 6s - loss: 1.7998 - accuracy: 0.3251 - 6s/epoch - 7ms/step
# Epoch 146/150
# 782/782 - 6s - loss: 1.7884 - accuracy: 0.3297 - 6s/epoch - 7ms/step
# Epoch 147/150
# 782/782 - 6s - loss: 1.7882 - accuracy: 0.3378 - 6s/epoch - 7ms/step
# Epoch 148/150
# 782/782 - 6s - loss: 1.7959 - accuracy: 0.3383 - 6s/epoch - 7ms/step
# Epoch 149/150
# 782/782 - 6s - loss: 1.7873 - accuracy: 0.3401 - 6s/epoch - 7ms/step
# Epoch 150/150
# 782/782 - 6s - loss: 1.7981 - accuracy: 0.3372 - 6s/epoch - 7ms/step

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
model.evaluate(x_test, y_test, batch_size=64, verbose=2)
# Out:
# 157/157 - 2s - loss: 1.5305 - accuracy: 0.4870 - 2s/epoch - 11ms/step
# [1.5305452346801758, 0.4869999885559082]
